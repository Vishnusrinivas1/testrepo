# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %%
print("\033[1m" + "VISHNU ILLENDULA"+ "\033[0m")

print("SAP Analyst")
# Out:
# VISHNU ILLENDULA
# SAP Analyst

# %%
 print("\x1B[3m "+ "I am Interested in data science because  i want to learn how the data helps Organizations to take decisions"+ "\x1B[0m")
# Out:
#  I am Interested in data science because  i want to learn how the data helps Organizations to take decisions

# %% [markdown]
# ### The below code is supposed to add , Multiply, subtract and divide

# %%
1+(22+2)/3*5-1
# Out:
# 40.0

# %% [markdown]
# <ul>
#
# <li>One</li>
# <li>Two</li>
# <li>Three</li>
# <li>Four</li>
#
# </ul>
